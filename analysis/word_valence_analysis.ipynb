# %%
import os
import pandas as pd
from twitter_bot.firebase import read_artist_dict, read_song_dict
from twitter_bot.process import lyric_tokenizer
import plotly.express as px

# %%
os.getcwd()
# Out:
# '/Users/carterward/Documents/GitHub/SongSentiment'

# %%
os.chdir('../')

# %%
hedonometer = pd.read_csv("data_and_models/Hedonometer.csv")

# %%
word_valence_dict = {row['Word']: row['Happiness Score'] for index, row in hedonometer.iterrows()}
word_std_dict = {row['Word']: row['Standard Deviation of Ratings'] for index, row in hedonometer.iterrows()}

# %%
fig = px.histogram(hedonometer, x="Standard Deviation of Ratings", nbins=15
)
fig.show()

# %%
fig = px.scatter(hedonometer, x="Happiness Score", y="Standard Deviation of Ratings", hover_data=['Word'])
fig.show()

# %%
lyrics = read_song_dict('frank ocean', 'self control')['lyrics']
tokenized_lyrics = lyric_tokenizer(lyrics)
print(tokenized_lyrics)
# Out:
# ['poolside', 'convo', 'summer', 'night', 'ooh', 'summer', 'night', 'play', 'mm', 'shive', 'night', 'shy', 'night', 'night', 'time', 'boyfriend', 'wet', 'dream', 'tonight', 'nose', 'rail', 'little', 'virgin', 'wear', 'white', 'cut', 'hair', 'use', 'live', 'blonde', 'life', 'wish', 'wish', 'grow', 'advice', 'time', 'right', 'place', 'sleep', 'place', 'miss', 'sound', 'cry', 'night', 'dance', 'tear', 'eye', 'come', 'visit', 'ufo', 'use', 'self', 'control', 'lose', 'self', 'control', 'self', 'control', 'place', 'sleep', 'place', 'thing', 'thing', 'miss', 'sound', 'cry', 'night', 'dance', 'tear', 'eye', 'know', 'got', 'leave', 'leave', 'leave', 'summer', 'time', 'tonight', 'night', 'night', 'know', 'comin', 'spittin', 'game', 'know', 'know', 'got', 'leave', 'leave', 'leave', 'summer', 'time', 'tonight', 'night', 'night', 'know', 'comin', 'spittin', 'game', 'know', 'know', 'got', 'leave', 'leave', 'leave', 'summer', 'time', 'tonight', 'night', 'night', 'know', 'comin', 'spittin', 'game', '
# ...

# %%
available_set = set(tokenized_lyrics) & set(hedonometer['Word'].values)
available_lyrics = [word for word in tokenized_lyrics if word in available_set]

# %%
print(len(tokenized_lyrics), len(available_set))
# Out:
# 115 48

# %%
unique_valence_scores = [word_valence_dict[word] for word in available_set]
unique_df = pd.DataFrame(valence_scores, columns=['unique_valence_scores'])
unique_df['word'] = available_set

# %%
fig = px.bar(unique_df,x = "word", y = "unique_valence_scores", title="valence on unique words in self control by frank ocean")
fig

# %%
fig.write_html("plots/valence_scores_in_self_control.html")

# %%
valence_scores = [word_valence_dict[word] for word in available_lyrics]
repeat_df = pd.DataFrame(valence_scores, columns=['valence_scores'])
repeat_df['word'] = available_lyrics

# %%
fig = px.histogram(df, x="valence_scores", nbins=10)
fig.show()

# %%
word_counts = [available_lyrics.count(word) for word in available_set]
unique_df['counts'] = word_counts

# %%
fig = px.bar(unique_df,x = "word", y = "counts", title="counts of words in self control by frank ocean")
fig

# %%
fig.write_html("plots/token_counts_in_self_control.html")

# %%
# Idea, we can trim the number of noisy features by removing tokens with high std deviations in their happiness scores: idea for threshhold: 1.5?

# %%
unique_df['valence_standard_deviation'] = [word_std_dict[word] for word in available_set]

# %%
fig = px.bar(unique_df,x = "word", y = "valence_standard_deviation", title="standard deviation of valence for words in self control by frank ocean")
fig

# %%
fig.write_html("plots/token_valence_standard_deviations.html")
